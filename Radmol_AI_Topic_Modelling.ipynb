# %% [markdown]
# # **Topic Modelling for Glioma, Leukaemia, and Retinoblastoma**

# %%
# !pip install session-info
# !pip install pycaret[full] --quiet
# !pip install bertopic --quiet
# !pip install --upgrade numpy
# !pip install bertopic[visualization] --quiet
# !pip install session-info
# Out:
# Requirement already satisfied: session-info in /usr/local/lib/python3.7/dist-packages (1.0.0)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.7/dist-packages (from session-info) (0.8.0)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# tensorflow 2.8.0 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# hdbscan 0.8.28 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.13.0 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.32.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# bertopic 0.9.4 requires numpy>=1.20.0, but you have numpy 1.19.5 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.21.6 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.13.0 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.32.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)
# WARNING: bertopic 0.9.4 does not provide the extra 'visualization'
# Requirement already satisfied: session-info in /usr/local/lib/python3.7/dist-packages (1.0.0)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.7/dist-packages (from session-info) (0.8.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pycaret.nlp import *
from bertopic import BERTopic
import session_info


from wordcloud import WordCloud

# %%
glioma = pd.read_csv('/content/glioma.csv')
leukaemia = pd.read_csv('/content/leukaemia.csv')
retino = pd.read_csv('/content/retinoblastoma.csv')

# %%
glioma.head()
# Out:
#                                             abstract
# 0  Surgeons have considered extending the resecti...
# 1  Following the identification of key molecular ...
# 2  To evaluate whether amide proton transfer (APT...
# 3  Diffusion-weighted imaging (DWI) plays an impo...
# 4  MRI is the standard imaging modality used for ...

# %%
leukaemia.head()
# Out:
#                                             abstract
# 0  Acute lymphoid leukaemia (ALL) is the commones...
# 1  Previous studies on the putative role of aller...
# 2  Although inferior outcomes of children with Do...
# 3  Treatment for adults with acute lymphoblastic ...
# 4  Acute Lymphoblastic Leukemia (ALL) is a neopla...

# %%
retino.head()
# Out:
#                                             abstract
# 0  To report three-decade changes of clinical cha...
# 1  Retinoblastoma, also known as ocular cancer, u...
# 2  Retinoblastoma, often referred to as eye cance...
# 3  We and others have shown that aberrant activat...
# 4  The bulb of Eleutherine bulbosa (Mill.) Urb. i...

# %%
print('glioma dataset: ', glioma.shape)
print('leukaemia dataset: ', leukaemia.shape)
print('retino dataset: ', retino.shape)
# Out:
# glioma dataset:  (4778, 1)
# leukaemia dataset:  (4413, 1)
# retino dataset:  (4418, 1)

# %%
print('glioma dataset null values: ', glioma.isnull().values.any())
print('leukaeamia dataset null values: ', leukaemia.isnull().values.any())
print('glioma dataset null values: ', retino.isnull().values.any())
# Out:
# glioma dataset null values:  True
# leukaeamia dataset null values:  True
# glioma dataset null values:  True

# %%
glioma.dropna(axis = 0, inplace = True)
leukaemia.dropna(axis = 0, inplace = True)
retino.dropna(axis = 0, inplace = True)

# %%
print('glioma dataset null values after drop: ', glioma.isnull().values.any())
print('leukaeamia dataset null values after drop: ', leukaemia.isnull().values.any())
print('glioma dataset null values after drop: ', retino.isnull().values.any())
# Out:
# glioma dataset null values after drop:  False
# leukaeamia dataset null values after drop:  False
# glioma dataset null values after drop:  False

# %% [markdown]
# # **Glioma Model**

# %%
glioma.head(10)
# Out:
#                                             abstract
# 0  Surgeons have considered extending the resecti...
# 1  Following the identification of key molecular ...
# 2  To evaluate whether amide proton transfer (APT...
# 3  Diffusion-weighted imaging (DWI) plays an impo...
# 4  MRI is the standard imaging modality used for ...
# 5  The BRAFV600E point mutation plays a key role ...
# 6  Grading of brain gliomas is of clinical import...
# 7  Anti-inflammatory effect of vitamin D (VD) cou...
# 8  Newly emerged molecular markers in gliomas pro...
# 9  According to the stem cell theory, two neuroge...

# %%
glioma_experiment = setup(glioma,
                          target = 'abstract',
                          session_id = 451)
# Out:
# <style type="text/css">
# </style>
# <table id="T_22bf9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_22bf9_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_22bf9_row0_col1" class="data row0 col1" >451</td>
#     </tr>
#     <tr>
#       <td id="T_22bf9_row1_col0" class="data row1 col0" >Documents</td>
#       <td id="T_22bf9_row1_col1" class="data row1 col1" >4777</td>
#     </tr>
#     <tr>
#       <td id="T_22bf9_row2_col0" class="data row2 col0" >Vocab Size</td>
#       <td id="T_22bf9_row2_col1" class="data row2 col1" >13749</td>
#     </tr>
#     <tr>
#       <td id="T_22bf9_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#       <td id="T_22bf9_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
models()
# Out:
#                                   Name                  Reference
# ID
# lda        Latent Dirichlet Allocation     gensim/models/ldamodel
# lsi           Latent Semantic Indexing     gensim/models/lsimodel
# hdp     Hierarchical Dirichlet Process     gensim/models/hdpmodel
# rp                  Random Projections      gensim/models/rpmodel
# nmf  Non-Negative Matrix Factorization  sklearn.decomposition.NMF

# %%
rp_model = create_model('rp')

# %%
print(rp_model)
# Out:
# RpModel(num_terms=13749, num_topics=4)

# %%
# Assign model results
rp_results = assign_model(rp_model)
rp_results.head()
# Out:
#                                             abstract  Topic_0  Topic_1  \
# 0  surgeon consider extend resection margin well ...      8.5     -1.5
# 1  follow identification key molecular alteration...    -13.0      1.0
# 2  evaluate use characterize pediatric patient pr...    -12.0    -29.0
# 3  image assessment however derive parameter mode...     -0.5    -12.5
# 4  modality use diagnosis treatment plan post tre...     -1.5     -5.5
#
#    Topic_2  Topic_3 Dominant_Topic
# 0     -1.5      6.5        Topic 0
# 1     11.0      2.0        Topic 2
# 2     11.0     -3.0        Topic 2
# 3      7.5     -1.5        Topic 2
# 4    -10.5      0.5        Topic 3

# %%
#Will identify the top 20 topics of the dataset
dataset = get_topics(rp_results, 'abstract', model = 'rp', num_topics = 20)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a55d4_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a55d4_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a55d4_row0_col1" class="data row0 col1" >3738</td>
#     </tr>
#     <tr>
#       <td id="T_a55d4_row1_col0" class="data row1 col0" >Documents</td>
#       <td id="T_a55d4_row1_col1" class="data row1 col1" >4778</td>
#     </tr>
#     <tr>
#       <td id="T_a55d4_row2_col0" class="data row2 col0" >Vocab Size</td>
#       <td id="T_a55d4_row2_col1" class="data row2 col1" >11298</td>
#     </tr>
#     <tr>
#       <td id="T_a55d4_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#       <td id="T_a55d4_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
dataset.fillna(rp_results.mean())
# Out:
#                                                abstract  Topic_0  Topic_1  \
# 0     surgeon consider extend resection margin outco...      8.5     -1.5
# 1     follow identification molecular alteration pro...    -13.0      1.0
# 2     evaluate use characterize pediatric patient pr...    -12.0    -29.0
# 3     image assessment however derive parameter mode...     -0.5    -12.5
# 4     modality use diagnosis treatment plan post tre...     -1.5     -5.5
# ...                                                 ...      ...      ...
# 4773  image show effective tool analysis discriminat...     -5.0    -15.0
# 4774  clinical significance decline free reference r...      1.5      1.5
# 4775  function include language calculation self mot...      4.5     -2.5
# 4776  characterize aggressive local growth pattern p...      3.5      8.5
# 4777  objective tumor group pediatric low grade aris...      NaN      NaN
#
#       Topic_2  Topic_3  Dominant_Topic   Topic_0   Topic_1   Topic_2  \
# 0        -1.5      6.5         Topic 0  0.223607  2.906888 -0.670820
# 1        11.0      2.0         Topic 2 -0.894427  0.447214  1.341641
# 2        11.0     -3.0         Topic 2 -3.577709  2.236068  5.813777
# 3         7.5     -1.5         Topic 2 -5.590170  6.484597  5.142956
# 4       -10.5      0.5         Topic 3 -1.118034  2.012461  4.248529
# ...       ...      ...             ...       ...       ...       ...
# 4773      4.0    -19.0         Topic 2  0.670820 -3.354102 -2.012461
# 4774      4.5     -5.5         Topic 2 -0.670820  6.037382  0.223607
# 4775    -11.5      3.5         Topic 0  1.788854  0.894427  0.894427
# 4776    -11.5     15.5         Topic 3  2.012461 -2.906889 -3.801316
# 4777      NaN      NaN             NaN -0.894427 -0.447214  4.024921
#
#        Topic_3  ...  Topic_11  Topic_12  Topic_13  Topic_14  Topic_15  \
# 0    -2.459675  ...  2.012461  1.118034 -1.118034 -1.118034  6.484597
# 1    -4.024922  ...  2.683282  0.894427 -2.683282 -1.341641  7.155417
# 2     1.341640  ...  3.130495  2.683282  4.024922 -5.366564  9.838698
# 3     1.565247  ...  1.118034 -0.223607  5.590170 -4.695743  6.931810
# 4    -2.906889  ...  0.670820  2.012461 -2.012461 -0.670821  7.379025
# ...        ...  ...       ...       ...       ...       ...       ...
# 4773 -7.379024  ...  3.801315  3.354102  1.118033  2.012461  6.931812
# 4774 -0.223607  ... -2.012461 -0.223607 -2.012461  4.695741 -1.565248
# 4775 -3.130495  ...  1.788854  1.788854 -1.341641 -0.894427 -0.894427
# 4776  1.565248  ...  1.118034  0.670820 -2.012461  2.906888 -2.012461
# 4777  2.236068  ... -1.788854 -1.341641 -4.024922 -1.341640  5.366563
#
#           Topic_16  Topic_17   Topic_18  Topic_19  Dominant_Topic
# 0     2.236066e-01  2.012461  -0.223607 -2.459675         Topic 8
# 1     1.788854e+00 -0.447214  -0.447213  1.788854        Topic 15
# 2     4.472132e-01 -1.788854 -10.733125 -4.472137         Topic 8
# 3     6.708202e-01  2.906888  -6.931810 -3.354103        Topic 15
# 4     2.906888e+00  5.142957  -2.012461  0.223607        Topic 15
# ...            ...       ...        ...       ...             ...
# 4773  9.615093e+00  6.037383  -8.720662 -6.931812        Topic 16
# 4774  2.012461e+00  2.459675  -2.459675 -0.670820         Topic 1
# 4775 -2.980232e-08  0.894427   2.236068 -0.447213        Topic 10
# 4776 -2.906888e+00  0.223606   3.801316  0.670820         Topic 6
# 4777  6.708202e+00  5.813777   2.236068  3.130494        Topic 16
#
# [4778 rows x 27 columns]

# %% [markdown]
# # **Topic Modelling with BerTopic**

# %%
# create model 
 
model = BERTopic(verbose=True)
 
#convert to list 
docs = glioma['abstract'].to_list()
 
topics, probabilities = model.fit_transform(docs)
# Out:
# Batches:   0%|          | 0/150 [00:00<?, ?it/s]
# 2022-04-16 12:30:17,980 - BERTopic - Transformed documents to Embeddings
# 2022-04-16 12:30:44,398 - BERTopic - Reduced dimensionality with UMAP
# 2022-04-16 12:30:44,625 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
#Select Top 50 Topics
model.get_topic_freq().head(50)
model.get_topic(50)
# Out:
# [('kurtosis', 0.07455368524034046),
#  ('dki', 0.05792902485537294),
#  ('diffusion', 0.04431173340490156),
#  ('mk', 0.03558022221593483),
#  ('metrics', 0.03037837645110476),
#  ('parameters', 0.022258190361098863),
#  ('fa', 0.02169953399126811),
#  ('mean', 0.020643893485974334),
#  ('diffusional', 0.01767338648471042),
#  ('md', 0.01742137998136389)]

# %%
#Frequency Visualization
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6a22d912-f4bd-481b-a22f-090a28d8d6e7" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a22d912-f4bd-481b-a22f-090a28d8d6e7")) {                    Plotly.newPlot(                        "6a22d912-f4bd-481b-a22f-090a28d8d6e7",                        [{"customdata":[[0,"braf | pediatric | mutations | tumors | in",171],[1,"children | pediatric | years | patients | chemotherapy",157],[2,"temozolomide | tmz | chemotherapy | patients | pcv",149],[3,"idh1 | mutations | mutation | idh | mutant",148],[4,"expression | glioma | tissues | mirnas | that",143],[5,"pet | uptake | petct | 18ffet | fet",117],[6,"survival | os | patients | factors | pfs",110],[7,"genes | signature | gene | lgg | expression",108],[8,"features | radiomics | segmentation | learning | machine",105],[9,"rcbv | cbv | volume | blood | cerebral",104],[10,"mrs | chocr | spectroscopy | ratios | chonaa",103],[11,"seizure | seizures | epilepsy | patients | control",90],[12,"immune | lgg | genes | infiltration | tcga",88],[13,"lggs | of | management | surgical | patients",73],[14,"fluorescence | 5ala | ppix | intraoperative | 5aminolevulinic",71],[15,"methylation | promoter | mgmt | ezh2 | in",67],[16,"qol | hrqol | depression | fatigue | life",59],[17,"cognitive | memory | surgery | neuropsychological | patients",54],[18,"loh | chromosome | 1p | deletion | loss",51],[19,"cells | immune | macrophages | tils | in",50],[20,"cognitive | neurocognitive | radiotherapy | rt | functioning",47],[21,"optic | visual | opg | nf1 | nerve",47],[22,"angiocentric | ag | case | lesion | the",44],[23,"motor | functional | mapping | the | resection",44],[24,"months | reirradiation | gy | median | dose",44],[25,"lncrnas | lncrna | noncoding | expression | rna",43],[26,"adc | values | diffusion | dwi | coefficient",43],[27,"expression | protein | glioma | tissues | cyclin",39],[28,"dti | tract | white | matter | tracts",38],[29,"ultrasound | intraoperative | us | 3d | lious",32],[30,"sign | idh | mismatch | idhmutant | t2flair",31],[31,"treatment | lowgrade | radiotherapy | chemotherapy | management",31],[32,"metabolic | metabolism | metabolites | glycolytic | cells",30],[33,"awake | craniotomy | mapping | eloquent | resection",29],[34,"brainstem | pineal | were | diagnosis | mri",29],[35,"nf1 | optic | mouse | neurofibromatosis | nerve",27],[36,"egfr | expression | egfrviii | factor | vegf",25],[37,"uptake | met | 11cmethionine | pet | tn",25],[38,"asl | cbf | arterial | perfusion | flow",24],[39,"proteins | protein | p27kip1 | expression | gntv",24],[40,"cells | cd133 | nestin | stem | expression",24],[41,"language | reorganization | functional | mapping | areas",23],[42,"connectivity | functional | network | networks | controls",23],[43,"fa | dti | md | diffusion | tensor",23],[44,"mathematical | model | growth | tumour | ecs",23],[45,"imri | resection | iomri | intraoperative | surgery",20],[46,"tert | alt | telomere | telomeres | htert",20],[47,"apt | aptw | transfer | amide | hggs",20],[48,"mobile | phone | allergies | use | risk",19],[49,"chordoid | ventricle | third | rare | myxoid",19],[50,"kurtosis | dki | diffusion | mk | metrics",19],[51,"nlr | plr | lmr | dnlr | preoperative",18],[52,"seizure | seizures | mutation | idh1 | idh12",18],[53,"resection | eloquent | functional | lggs | intraoperative",17],[54,"bevacizumab | children | median | range | response",17],[55,"sbt | brachytherapy | seeds | iodine125 | stereotactic",16],[56,"polymorphisms | risk | genotype | snps | genotypes",16],[57,"insular | eor | resection | insula | zone",16],[58,"vegf | angiogenesis | endothelial | endocan | vestatinegfl7",16],[59,"mmp1 | emmprin | mmp2 | rap2b | robo4",15],[60,"tectal | hydrocephalus | endoscop ...

# %%
#Barchart Visualization
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f03e8bc4-c77a-422c-a527-3430f4468dbc" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f03e8bc4-c77a-422c-a527-3430f4468dbc")) {                    Plotly.newPlot(                        "f03e8bc4-c77a-422c-a527-3430f4468dbc",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.012770493866662425,0.013200692457446749,0.01440155485108976,0.026833011983437904,0.027769025332080883],"y":["in  ","tumors  ","mutations  ","pediatric  ","braf  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.012473791466658503,0.014256631664660553,0.0142733948527742,0.016476483662761877,0.022778551811680686],"y":["chemotherapy  ","patients  ","years  ","pediatric  ","children  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.01291284137955398,0.013163078609556204,0.016598222766301816,0.01955799038293256,0.023787521291431274],"y":["pcv  ","patients  ","chemotherapy  ","tmz  ","temozolomide  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.019316340410206915,0.023206549592536502,0.023531542372040654,0.02879965461581717,0.03843564907590166],"y":["mutant  ","idh  ","mutation  ","mutations  ","idh1  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.015563861383745653,0.015615472025394863,0.0210531370927988,0.02423728907236219,0.02901480170563967],"y":["that  ","mirnas  ","tissues  ","glioma  ","expression  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.014764551691628812,0.017021004888224067,0.018780807453669914,0.031343568705986626,0.04067321583044163],"y":["fet  ","18ffet  ","petct  ","uptake  ","pet  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.013876646143383376,0.014956031124927783,0.01771845647075108,0.018183697354777262,0.019649026771028883],"y":["pfs  ","factors  ","patients  ","os  ","survival  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01747636959847837,0.018341019675147195,0.018654372007568355,0.02090035042590715,0.023668452680641328],"y":["expression  ","lgg  ","gene  ","signature  ","genes  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e ...

# %%
#Topic Similarity
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2cfd82ef-02c6-4981-8ccc-d7ec5f2f119d" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cfd82ef-02c6-4981-8ccc-d7ec5f2f119d")) {                    Plotly.newPlot(                        "2cfd82ef-02c6-4981-8ccc-d7ec5f2f119d",                        [{"coloraxis":"coloraxis","name":"0","x":["-1_and_in_of","0_braf_pediatric_mutations","1_children_pediatric_years","2_temozolomide_tmz_chemothe...","3_idh1_mutations_mutation","4_expression_glioma_tissues","5_pet_uptake_petct","6_survival_os_patients","7_genes_signature_gene","8_features_radiomics_segmen...","9_rcbv_cbv_volume","10_mrs_chocr_spectroscopy","11_seizure_seizures_epilepsy","12_immune_lgg_genes","13_lggs_of_management","14_fluorescence_5ala_ppix","15_methylation_promoter_mgmt","16_qol_hrqol_depression","17_cognitive_memory_surgery","18_loh_chromosome_1p","19_cells_immune_macrophages","20_cognitive_neurocognitive...","21_optic_visual_opg","22_angiocentric_ag_case","23_motor_functional_mapping","24_months_reirradiation_gy","25_lncrnas_lncrna_noncoding","26_adc_values_diffusion","27_expression_protein_glioma","28_dti_tract_white","29_ultrasound_intraoperativ...","30_sign_idh_mismatch","31_treatment_lowgrade_radio...","32_metabolic_metabolism_met...","33_awake_craniotomy_mapping","34_brainstem_pineal_were","35_nf1_optic_mouse","36_egfr_expression_egfrviii","37_uptake_met_11cmethionine","38_asl_cbf_arterial","39_proteins_protein_p27kip1","40_cells_cd133_nestin","41_language_reorganization_...","42_connectivity_functional_...","43_fa_dti_md","44_mathematical_model_growth","45_imri_resection_iomri","46_tert_alt_telomere","47_apt_aptw_transfer","48_mobile_phone_allergies","49_chordoid_ventricle_third","50_kurtosis_dki_diffusion","51_nlr_plr_lmr","52_seizure_seizures_mutation","53_resection_eloquent_funct...","54_bevacizumab_children_med...","55_sbt_brachytherapy_seeds","56_polymorphisms_risk_genot...","57_insular_eor_resection","58_vegf_angiogenesis_endoth...","59_mmp1_emmprin_mmp2","60_tectal_hydrocephalus_end...","61_proton_therapy_prt","62_neuroepithelial_dnt_leat","63_transformation_measureme...","64_hcmv_viral_infection","65_usp2a_expression_nrf2","66_hr_survival_molecular","67_egfr_growth_mpa","68_texture_mdf_using","69_mtd_chemotherapy_decrease","70_resection_studies_extent","71_imaging_mr_sequences"],"y":["-1_and_in_of","0_braf_pediatric_mutations","1_children_pediatric_years","2_temozolomide_tmz_chemothe...","3_idh1_mutations_mutation","4_expression_glioma_tissues","5_pet_uptake_petct","6_survival_os_patients","7_genes_signature_gene","8_features_radiomics_segmen...","9_rcbv_cbv_volume","10_mrs_chocr_spectroscopy","11_seizure_seizures_epilepsy","12_immune_lgg_genes","13_lggs_of_management","14_fluorescence_5ala_ppix","15_methylation_promoter_mgmt","16_qol_hrqol_depression","17_cognitive_memory_surgery","18_loh_chromosome_1p","19_cells_immune_macrophages","20_cognitive_neurocognitive...","21_optic_visual_opg","22_angiocentric_ag_case","23_motor_functional_mapping","24_months_reirradiation_gy","25_lncrnas_lncrna_noncoding","26_adc_values_diffusion","27_expression_protein_glioma","28_dti_tract_white","29_ultrasound_intraoperativ...","30_sign_idh_mismatch","31_treatment_lowgrade_radio...","32_metabolic_metabolism_met...","33_awake_craniotomy_mapping","34_brainstem_pineal_were","35_nf1_optic_mouse","36_egfr_expression_egfrviii","37_uptake_met_11cmethionine","38_asl_cbf_arterial","39_proteins_protein_p27kip1","40_cells_cd133_nestin","41_language_reorganization_...","42_connectivity_functional_...","43_fa_dti_md","44_mathematical_model_growth","45_imri_resection_iomri","46_tert_alt_telomere","47_apt_aptw_transfer","48_mobile_phone_allergies","49_chordoid_ventricle_third","50_kurtosis_ ...

# %%
#Predict New Topics of any document...just add your dataframe when needed
#topics, probs = model.transform()

# %% [markdown]
# # **Leukaemia Model**

# %%
leukaemia.head(10)
# Out:
#                                             abstract
# 0  Acute lymphoid leukaemia (ALL) is the commones...
# 1  Previous studies on the putative role of aller...
# 2  Although inferior outcomes of children with Do...
# 3  Treatment for adults with acute lymphoblastic ...
# 4  Acute Lymphoblastic Leukemia (ALL) is a neopla...
# 5  Acute lymphoblastic leukaemia develops in both...
# 6  Gender-specific differences in survival by cli...
# 7  The prognostic value of minimal residual disea...
# 8  T-cell acute lymphoblastic leukemia is a relat...
# 9  To investigate the clinical characteristics of...

# %%
leukaemia_experiment = setup(leukaemia,
                          target = 'abstract',
                          session_id = 451)
# Out:
# <style type="text/css">
# </style>
# <table id="T_37017_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_37017_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_37017_row0_col1" class="data row0 col1" >451</td>
#     </tr>
#     <tr>
#       <td id="T_37017_row1_col0" class="data row1 col0" >Documents</td>
#       <td id="T_37017_row1_col1" class="data row1 col1" >4409</td>
#     </tr>
#     <tr>
#       <td id="T_37017_row2_col0" class="data row2 col0" >Vocab Size</td>
#       <td id="T_37017_row2_col1" class="data row2 col1" >12703</td>
#     </tr>
#     <tr>
#       <td id="T_37017_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#       <td id="T_37017_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# create model 
 
model = BERTopic(verbose=True)
 
#convert to list 
docs = leukaemia['abstract'].to_list()
 
topics, probabilities = model.fit_transform(docs)
# Out:
# Batches:   0%|          | 0/138 [00:00<?, ?it/s]
# 2022-04-16 12:32:29,327 - BERTopic - Transformed documents to Embeddings
# 2022-04-16 12:32:42,591 - BERTopic - Reduced dimensionality with UMAP
# 2022-04-16 12:32:42,809 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
#Select Top 50 Topics
model.get_topic_freq().head(50)
model.get_topic(50)
# Out:
# [('osteonecrosis', 0.05371599616967559),
#  ('on', 0.03866459156267535),
#  ('symptomatic', 0.02504233145039871),
#  ('mri', 0.021849417539431766),
#  ('head', 0.019889738113691928),
#  ('femoral', 0.018153634717289487),
#  ('joints', 0.01784240567775489),
#  ('children', 0.015397408392352563),
#  ('incidence', 0.015267962655697269),
#  ('hips', 0.014988535849477399)]

# %%
#Frequency Visualization
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8e522138-a0e3-4bfa-94b0-a156a5fce5b7" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e522138-a0e3-4bfa-94b0-a156a5fce5b7")) {                    Plotly.newPlot(                        "8e522138-a0e3-4bfa-94b0-a156a5fce5b7",                        [{"customdata":[[0,"transplantation | patients | donor | hsct | os",202],[1,"apoptosis | cells | cell | that | of",179],[2,"survival | years | were | children | the",130],[3,"cart | car | cells | antigen | crs",126],[4,"expression | mirnas | mirna | proliferation | cell",122],[5,"asparaginase | lasparaginase | hypersensitivity | pancreatitis | activity",111],[6,"cells | bm | mice | microenvironment | ball",78],[7,"mrd | flow | samples | cytometry | detection",73],[8,"association | snps | polymorphisms | genotype | risk",69],[9,"obesity | survivors | bmi | intake | body",67],[10,"blinatumomab | rr | cr | patients | relapsedrefractory",66],[11,"rituximab | antibodies | monoclonal | therapies | antigen",65],[12,"mrd | residual | minimal | at | patients",63],[13,"6mp | nudt15 | tpmt | variants | dose",59],[14,"mutations | mutation | relapse | alterations | sequencing",57],[15,"methylation | dna | epigenetic | promoter | in",52],[16,"survivors | neurocognitive | cognitive | attention | brain",51],[17,"mtx | methotrexate | polymorphisms | mthfr | toxicity",49],[18,"sleep | parents | children | anxiety | quality",48],[19,"expression | genes | gene | mrna | degs",47],[20,"ponatinib | tkis | ph | kinase | tki",47],[21,"ikzf1 | deletions | deletion | ik6 | ikaros",46],[22,"fusion | gene | genes | znf384 | ep300znf384",45],[23,"imatinib | dasatinib | patients | ph | molecular",45],[24,"cns | tlp | nervous | central | involvement",44],[25,"cytogenetic | abnormalities | chromosomal | chromosomes | fish",44],[26,"gc | resistance | glucocorticoid | gcs | glucocorticoids",44],[27,"tki | ph | hsct | tkis | allohsct",43],[28,"conditioning | tbi | regimen | irradiation | cy",40],[29,"bcrabl1like | bcrabl1 | fusion | phlike | ibcrabl1ilike",39],[30,"fungal | invasive | ifi | infection | mucormycosis",37],[31,"notch | tall | notch1 | signaling | that",34],[32,"aya | ayas | young | adult | hypercvad",33],[33,"mediastinal | lymphoma | cases | tlbl | lbl",31],[34,"prebcr | ikaros | il7r | signaling | il7",31],[35,"vte | thrombosis | venous | cvt | thromboembolism",30],[36,"mtx | hdmtx | methotrexate | aki | egfr",30],[37,"nk | cells | kir | killer | ligands",29],[38,"fgfr1 | mm | neoplasms | secondary | case",29],[39,"expression | cd45 | cd146 | cd71 | patients",28],[40,"clofarabine | bortezomib | liposomal | cr | patients",27],[41,"cutaneous | blbl | uterine | lymphoma | rare",26],[42,"ocular | optic | eye | nerve | visual",26],[43,"ino | inotuzumab | ozogamicin | sc | rr",26],[44,"jak2 | jak | jak3 | jakstat | ruxolitinib",24],[45,"etv6runx1 | evi1 | expression | we | dhx15",24],[46,"infections | infection | bacteremia | during | episodes",24],[47,"myc | rearrangement | balllbl | hs | rare",22],[48,"csf | cns | involvement | fluid | nervous",22],[49,"etv6runx1 | etv6runx1positive | twins | runx1 | fusion",22],[50,"osteonecrosis | on | symptomatic | mri | head",22],[51,"cardiac | doxorubicin | cardiotoxicity | strain | systolic",20],[52,"etpall | etp | nonetp | tall | tcell",19],[53,"slc2a5 | childhood | genomic | all | treatment",19],[54,"crlf2 | p2ry8crlf2 | ikzf1 | deletions | expression",17],[55,"accuracy | images | learning | model | machine",17],[56,"elderly | older | patients | adults | ph",17],[57,"therapies | new | novel | relapsed | all",17],[58,"maternal | exposure | 95 | ci | risk",17],[59,"nanoparticles | 6mpns | bp | cells | agnps",16],[60,"lpcs | phsupsupall | tcell | all | are",16],[61,"bmd | zsco ...

# %%
#Barchart Visualization
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5b4c5f7e-4ca0-4be5-b307-338b98ef835e" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b4c5f7e-4ca0-4be5-b307-338b98ef835e")) {                    Plotly.newPlot(                        "5b4c5f7e-4ca0-4be5-b307-338b98ef835e",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.013138127595243881,0.013289007963304478,0.013688556629388822,0.014388586962634823,0.01849178678650002],"y":["os  ","hsct  ","donor  ","patients  ","transplantation  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.012124025883404806,0.01247041723658714,0.01858793109327272,0.019167576362823822,0.020263264151777108],"y":["of  ","that  ","cell  ","cells  ","apoptosis  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.011311960993231503,0.012481822591110607,0.01370603374997106,0.014026845950274924,0.01429301810485695],"y":["the  ","children  ","were  ","years  ","survival  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.018229824832741257,0.018244823412350994,0.018634719360129042,0.03231779481867362,0.040062213225883714],"y":["crs  ","antigen  ","cells  ","car  ","cart  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.013881491890615338,0.01420090809150514,0.015847433589142975,0.020983633575681032,0.023956993083866486],"y":["cell  ","proliferation  ","mirna  ","mirnas  ","expression  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.015349858078426704,0.017278153326640826,0.017961334181445562,0.021201905980098933,0.04726277514262162],"y":["activity  ","pancreatitis  ","hypersensitivity  ","lasparaginase  ","asparaginase  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.013772936647362708,0.015135256227351922,0.015903811950867236,0.01886640487499601,0.030149691753849503],"y":["ball  ","microenvironment  ","mice  ","bm  ","cells  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.017388219852114122,0.017808756965131387,0.01798575982576078,0.02049236324109406,0.04288358495262581],"y":["detection  ","cytometry  ","samples  ","flow  ","mrd  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333 ...

# %%
#Topic Similarity
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0c525802-8706-4bed-a3fd-f048ec3f6c51" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c525802-8706-4bed-a3fd-f048ec3f6c51")) {                    Plotly.newPlot(                        "0c525802-8706-4bed-a3fd-f048ec3f6c51",                        [{"coloraxis":"coloraxis","name":"0","x":["-1_of_and_the","0_transplantation_patients_...","1_apoptosis_cells_cell","2_survival_years_were","3_cart_car_cells","4_expression_mirnas_mirna","5_asparaginase_lasparaginas...","6_cells_bm_mice","7_mrd_flow_samples","8_association_snps_polymorp...","9_obesity_survivors_bmi","10_blinatumomab_rr_cr","11_rituximab_antibodies_mon...","12_mrd_residual_minimal","13_6mp_nudt15_tpmt","14_mutations_mutation_relapse","15_methylation_dna_epigenetic","16_survivors_neurocognitive...","17_mtx_methotrexate_polymor...","18_sleep_parents_children","19_expression_genes_gene","20_ponatinib_tkis_ph","21_ikzf1_deletions_deletion","22_fusion_gene_genes","23_imatinib_dasatinib_patie...","24_cns_tlp_nervous","25_cytogenetic_abnormalitie...","26_gc_resistance_glucocorti...","27_tki_ph_hsct","28_conditioning_tbi_regimen","29_bcrabl1like_bcrabl1_fusion","30_fungal_invasive_ifi","31_notch_tall_notch1","32_aya_ayas_young","33_mediastinal_lymphoma_cases","34_prebcr_ikaros_il7r","35_vte_thrombosis_venous","36_mtx_hdmtx_methotrexate","37_nk_cells_kir","38_fgfr1_mm_neoplasms","39_expression_cd45_cd146","40_clofarabine_bortezomib_l...","41_cutaneous_blbl_uterine","42_ocular_optic_eye","43_ino_inotuzumab_ozogamicin","44_jak2_jak_jak3","45_etv6runx1_evi1_expression","46_infections_infection_bac...","47_myc_rearrangement_balllbl","48_csf_cns_involvement","49_etv6runx1_etv6runx1posit...","50_osteonecrosis_on_symptom...","51_cardiac_doxorubicin_card...","52_etpall_etp_nonetp","53_slc2a5_childhood_genomic","54_crlf2_p2ry8crlf2_ikzf1","55_accuracy_images_learning","56_elderly_older_patients","57_therapies_new_novel","58_maternal_exposure_95","59_nanoparticles_6mpns_bp","60_lpcs_phsupsupall_tcell","61_bmd_zscores_density","62_tisagenlecleucel_ctl019_...","63_mthfr_rs1801133_c677t","64_tisagenlecleucel_costs_c...","65_oral_mucositis_dental","66_hispanic_black_children","67_neuropathy_vincristine_v...","68_survivors_exercise_physi...","69_di_experimental_vincrist...","70_hypercalcemia_bone_pain","71_covid19_infection_sarscov2","72_ds_dsall_down","73_itcri_rearrangement_tran...","74_cmv_atl_reactivation","75_cns_emr_relapse","76_vitamin_bmd_deficiency","77_constipation_igg_siadh","78_copy_deletions_number","79_panobinostat_wntcatenin_..."],"y":["-1_of_and_the","0_transplantation_patients_...","1_apoptosis_cells_cell","2_survival_years_were","3_cart_car_cells","4_expression_mirnas_mirna","5_asparaginase_lasparaginas...","6_cells_bm_mice","7_mrd_flow_samples","8_association_snps_polymorp...","9_obesity_survivors_bmi","10_blinatumomab_rr_cr","11_rituximab_antibodies_mon...","12_mrd_residual_minimal","13_6mp_nudt15_tpmt","14_mutations_mutation_relapse","15_methylation_dna_epigenetic","16_survivors_neurocognitive...","17_mtx_methotrexate_polymor...","18_sleep_parents_children","19_expression_genes_gene","20_ponatinib_tkis_ph","21_ikzf1_deletions_deletion","22_fusion_gene_genes","23_imatinib_dasatinib_patie...","24_cns_tlp_nervous","25_cytogenetic_abnormalitie...","26_gc_resistance_glucocorti...","27_tki_ph_hsct","28_conditioning_tbi_regimen","29_bcrabl1like_bcrabl1_fusion","30_fungal_invasive_ifi","31_notch_tall_notch1","32_aya_ayas_young","33_mediastinal_lymphoma_cases","34_prebcr_ikaros_il7r","35_vte_thrombosis_venous","36_mtx_hdmtx_methotrexate","37_nk_cells_kir","38_fgfr1_mm_neoplasms","39_expression_cd45_cd146","40_clofarabine_bortezomib_l...","41_cutaneous_blbl_uterine","42_ocular_optic_eye" ...

# %%
#Predict New Topics of any document...just add your dataframe when needed
#topics, probs = model.transform()

# %% [markdown]
# # **Retinoblastoma Model**

# %%
retino.head(10)
# Out:
#                                             abstract
# 0  To report three-decade changes of clinical cha...
# 1  Retinoblastoma, also known as ocular cancer, u...
# 2  Retinoblastoma, often referred to as eye cance...
# 3  We and others have shown that aberrant activat...
# 4  The bulb of Eleutherine bulbosa (Mill.) Urb. i...
# 5  This study attempted to estimate the impact of...
# 6  To determine the risk of patients with an earl...
# 7  This case report presents two patients affecte...
# 8  Intra-arterial chemotherapy (IAC) represents a...
# 9  Long non-coding RNAs (lncRNAs) have been shown...

# %%
retino_experiment = setup(leukaemia,
                          target = 'abstract',
                          session_id = 451)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c94fb_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c94fb_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_c94fb_row0_col1" class="data row0 col1" >451</td>
#     </tr>
#     <tr>
#       <td id="T_c94fb_row1_col0" class="data row1 col0" >Documents</td>
#       <td id="T_c94fb_row1_col1" class="data row1 col1" >4409</td>
#     </tr>
#     <tr>
#       <td id="T_c94fb_row2_col0" class="data row2 col0" >Vocab Size</td>
#       <td id="T_c94fb_row2_col1" class="data row2 col1" >12703</td>
#     </tr>
#     <tr>
#       <td id="T_c94fb_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#       <td id="T_c94fb_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# create model 
 
model = BERTopic(verbose=True)
 
#convert to list 
docs = leukaemia['abstract'].to_list()
 
topics, probabilities = model.fit_transform(docs)
# Out:
# Batches:   0%|          | 0/138 [00:00<?, ?it/s]
# 2022-04-16 12:34:21,990 - BERTopic - Transformed documents to Embeddings
# 2022-04-16 12:34:35,149 - BERTopic - Reduced dimensionality with UMAP
# 2022-04-16 12:34:35,364 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
#Select Top 50 Topics
model.get_topic_freq().head(50)
model.get_topic(50)
# Out:
# [('allogeneic', 0.023173336999210224),
#  ('transplantation', 0.020857061988340923),
#  ('os', 0.01931048844939952),
#  ('patients', 0.01795845118438476),
#  ('survival', 0.015701775516315807),
#  ('adult', 0.015192230106864383),
#  ('hsct', 0.015055667379819766),
#  ('skeletal', 0.01417938157566772),
#  ('sall', 0.014054698364659782),
#  ('remission', 0.013529175322521481)]

# %%
#Frequency Visualization
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8e590c48-448d-4a37-ab5f-ff15cc70ce93" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e590c48-448d-4a37-ab5f-ff15cc70ce93")) {                    Plotly.newPlot(                        "8e590c48-448d-4a37-ab5f-ff15cc70ce93",                        [{"customdata":[[0,"cart | car | antigen | crs | chimeric",156],[1,"years | were | survival | children | the",149],[2,"expression | mirnas | mirna | proliferation | cell",120],[3,"asparaginase | lasparaginase | hypersensitivity | pancreatitis | activity",114],[4,"donor | gvhd | transplantation | donors | unrelated",84],[5,"mtx | mthfr | polymorphisms | polymorphism | methotrexate",75],[6,"cells | bm | cxcr4 | microenvironment | mice",74],[7,"association | snps | polymorphisms | risk | polymorphism",70],[8,"rituximab | antibodies | therapies | monoclonal | bispecific",67],[9,"obesity | survivors | bmi | intake | body",67],[10,"blinatumomab | rr | relapsedrefractory | cycles | patients",64],[11,"tlbl | lymphoma | mediastinal | lbl | cases",64],[12,"mutations | mutation | genetic | sequencing | flt3",62],[13,"methylation | dna | epigenetic | that | histone",62],[14,"6mp | nudt15 | tpmt | variants | dose",58],[15,"ponatinib | tkis | ph | kinase | tki",56],[16,"survivors | neurocognitive | cognitive | attention | brain",51],[17,"mrd | residual | minimal | at | patients",51],[18,"sleep | parents | children | anxiety | quality",48],[19,"tki | ph | tkis | allohsct | hsct",46],[20,"ikzf1 | deletions | deletion | iikzf1i | cdkn2ab",44],[21,"imatinib | dasatinib | patients | ph | philadelphia",44],[22,"gc | resistance | glucocorticoid | gcs | glucocorticoids",44],[23,"bcrabl1like | bcrabl1 | phlike | abl1 | fusion",43],[24,"cytogenetic | abnormalities | chromosomes | chromosomal | fish",43],[25,"fusion | genes | gene | znf384 | ep300znf384",43],[26,"infection | infections | cmv | during | viral",43],[27,"osteonecrosis | on | pain | hypercalcemia | bone",43],[28,"ros | cells | apoptosis | death | cell",42],[29,"conditioning | tbi | regimen | irradiation | cy",40],[30,"etv6runx1 | e2apbx1 | evi1 | expression | that",37],[31,"cns | tlp | nervous | central | crt",36],[32,"aya | ayas | young | adult | hypercvad",35],[33,"fungal | ifi | invasive | mucormycosis | infection",35],[34,"cutaneous | blbl | lymphoma | uterine | biopsy",33],[35,"apoptosis | trail | cell | cells | lines",31],[36,"ino | inotuzumab | ozogamicin | rr | blinatumomab",31],[37,"mtx | hdmtx | methotrexate | aki | egfr",30],[38,"notch | tall | notch1 | signaling | tcell",30],[39,"vte | thrombosis | venous | cvt | thromboembolism",29],[40,"nk | cells | kir | killer | ligands",28],[41,"ocular | optic | eye | nerve | visual",26],[42,"jak2 | jak | jak3 | jakstat | mutations",25],[43,"myc | rearrangement | balllbl | bl | rare",25],[44,"mtor | rapamycin | autophagy | pi3k | inhibitors",24],[45,"etv6runx1 | runx1 | etv6runx1positive | etv6 | twins",24],[46,"csf | cns | involvement | fluid | nervous",24],[47,"expression | ars2 | proteins | livin | prognostic",24],[48,"mm | fgfr1 | secondary | lenalidomide | myeloma",23],[49,"mrd | hts | monitoring | pcr | sequencing",23],[50,"allogeneic | transplantation | os | patients | survival",22],[51,"nelarabine | therapies | relapsed | mer | new",21],[52,"maternal | exposure | 95 | ci | childhood",20],[53,"cardiac | doxorubicin | cardiotoxicity | strain | systolic",20],[54,"slc2a5 | genomic | childhood | treatment | genetic",20],[55,"ikaros | prebcr | il7r | signaling | ck2",20],[56,"bmd | zscores | density | mineral | bone",19],[57,"etpall | nonetp | etp | tall | tcell",18],[58,"hispanic | black | children | latinos | nonhispanic",17],[59,"expression | cd45 | cd146 | cd71 | cd27",17],[60,"mrd | detection |  ...

# %%
#Barchart Visualization
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c5eaee55-6eba-4d97-af1c-dce79fff87f6" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5eaee55-6eba-4d97-af1c-dce79fff87f6")) {                    Plotly.newPlot(                        "c5eaee55-6eba-4d97-af1c-dce79fff87f6",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.016666342239064533,0.017362532691263505,0.017636369433917515,0.030944952444040857,0.03368296445429531],"y":["chimeric  ","crs  ","antigen  ","car  ","cart  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.011088267243294285,0.011853959020425362,0.013356669363857059,0.013674969630036882,0.014176817382765439],"y":["the  ","children  ","survival  ","were  ","years  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.013759285332538474,0.01420430739301952,0.016162848657565454,0.02139761839338775,0.024139670155199675],"y":["cell  ","proliferation  ","mirna  ","mirnas  ","expression  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.015164969838950585,0.016949273781300876,0.01762169374078203,0.021916896302583148,0.04632658198393609],"y":["activity  ","pancreatitis  ","hypersensitivity  ","lasparaginase  ","asparaginase  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.01434727458529025,0.015365952363775064,0.02082537901570158,0.023308644618030637,0.023625360569343425],"y":["unrelated  ","donors  ","transplantation  ","gvhd  ","donor  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.01833556823234906,0.01968620447533138,0.023422151432613364,0.02827491367084822,0.04659658137380914],"y":["methotrexate  ","polymorphism  ","polymorphisms  ","mthfr  ","mtx  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.0151927736747599,0.01549015861768044,0.016300114079244893,0.01944106629942003,0.027702571611259212],"y":["mice  ","microenvironment  ","cxcr4  ","bm  ","cells  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01621412284212947,0.01679223301302221,0.017412831772124684,0.01826278734230148,0.019418279934221218],"y":["polymorphism  ","risk  ","polymorphisms  ","snps  ","association  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22 ...

# %%
#Topic Similarity
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6e99fb7a-d2d0-4535-aa7c-fa69d60aa5d9" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e99fb7a-d2d0-4535-aa7c-fa69d60aa5d9")) {                    Plotly.newPlot(                        "6e99fb7a-d2d0-4535-aa7c-fa69d60aa5d9",                        [{"coloraxis":"coloraxis","name":"0","x":["-1_of_and_the","0_cart_car_antigen","1_years_were_survival","2_expression_mirnas_mirna","3_asparaginase_lasparaginas...","4_donor_gvhd_transplantation","5_mtx_mthfr_polymorphisms","6_cells_bm_cxcr4","7_association_snps_polymorp...","8_rituximab_antibodies_ther...","9_obesity_survivors_bmi","10_blinatumomab_rr_relapsed...","11_tlbl_lymphoma_mediastinal","12_mutations_mutation_genetic","13_methylation_dna_epigenetic","14_6mp_nudt15_tpmt","15_ponatinib_tkis_ph","16_survivors_neurocognitive...","17_mrd_residual_minimal","18_sleep_parents_children","19_tki_ph_tkis","20_ikzf1_deletions_deletion","21_imatinib_dasatinib_patie...","22_gc_resistance_glucocorti...","23_bcrabl1like_bcrabl1_phlike","24_cytogenetic_abnormalitie...","25_fusion_genes_gene","26_infection_infections_cmv","27_osteonecrosis_on_pain","28_ros_cells_apoptosis","29_conditioning_tbi_regimen","30_etv6runx1_e2apbx1_evi1","31_cns_tlp_nervous","32_aya_ayas_young","33_fungal_ifi_invasive","34_cutaneous_blbl_lymphoma","35_apoptosis_trail_cell","36_ino_inotuzumab_ozogamicin","37_mtx_hdmtx_methotrexate","38_notch_tall_notch1","39_vte_thrombosis_venous","40_nk_cells_kir","41_ocular_optic_eye","42_jak2_jak_jak3","43_myc_rearrangement_balllbl","44_mtor_rapamycin_autophagy","45_etv6runx1_runx1_etv6runx...","46_csf_cns_involvement","47_expression_ars2_proteins","48_mm_fgfr1_secondary","49_mrd_hts_monitoring","50_allogeneic_transplantati...","51_nelarabine_therapies_rel...","52_maternal_exposure_95","53_cardiac_doxorubicin_card...","54_slc2a5_genomic_childhood","55_ikaros_prebcr_il7r","56_bmd_zscores_density","57_etpall_nonetp_etp","58_hispanic_black_children","59_expression_cd45_cd146","60_mrd_detection_samples","61_mrd_hgs_transplantation","62_crlf2_p2ry8crlf2_deletions","63_elderly_adults_older","64_nanoparticles_6mpns_bp","65_tisagenlecleucel_costs_c...","66_survivors_exercise_physi...","67_oral_dental_mucositis","68_vitamin_deficiency_bmd","69_neuropathy_vincristine_v...","70_images_accuracy_proposed","71_cdk6_stip_oridonin","72_clofarabine_dose_cr","73_ds_dsall_down","74_di_experimental_prd","75_bortezomib_proteasome_pk","76_covid19_infection_sarscov2","77_copy_deletions_number","78_constipation_igg_siadh","79_rearrangements_itcri_rea...","80_tcell_approaches_exhausted"],"y":["-1_of_and_the","0_cart_car_antigen","1_years_were_survival","2_expression_mirnas_mirna","3_asparaginase_lasparaginas...","4_donor_gvhd_transplantation","5_mtx_mthfr_polymorphisms","6_cells_bm_cxcr4","7_association_snps_polymorp...","8_rituximab_antibodies_ther...","9_obesity_survivors_bmi","10_blinatumomab_rr_relapsed...","11_tlbl_lymphoma_mediastinal","12_mutations_mutation_genetic","13_methylation_dna_epigenetic","14_6mp_nudt15_tpmt","15_ponatinib_tkis_ph","16_survivors_neurocognitive...","17_mrd_residual_minimal","18_sleep_parents_children","19_tki_ph_tkis","20_ikzf1_deletions_deletion","21_imatinib_dasatinib_patie...","22_gc_resistance_glucocorti...","23_bcrabl1like_bcrabl1_phlike","24_cytogenetic_abnormalitie...","25_fusion_genes_gene","26_infection_infections_cmv","27_osteonecrosis_on_pain","28_ros_cells_apoptosis","29_conditioning_tbi_regimen","30_etv6runx1_e2apbx1_evi1","31_cns_tlp_nervous","32_aya_ayas_young","33_fungal_ifi_invasive","34_cutaneous_blbl_lymphoma","35_apoptosis_trail_cell","36_ino_inotuzumab_ozogamicin","37_mtx_hdmtx_methotrexate","38_notch_tall_notch1","39_vte_thrombosis_venous","40_nk_cells_kir","41 ...

# %%
session_info.show(html=False)
# Out:
# -----
# bertopic            0.9.4
# gensim              3.6.0
# matplotlib          3.5.1
# numpy               1.21.6
# pandas              1.3.5
# plotly              5.5.0
# pycaret             2.3.10
# seaborn             0.11.2
# session_info        1.0.0
# wordcloud           1.5.0
# -----
# IPython             7.32.0
# jupyter_client      7.2.2
# jupyter_core        4.9.2
# notebook            5.3.1
# -----
# Python 3.7.13 (default, Mar 16 2022, 17:37:17) [GCC 7.5.0]
# Linux-5.4.144+-x86_64-with-Ubuntu-18.04-bionic
# -----
# Session information updated at 2022-04-16 12:39
